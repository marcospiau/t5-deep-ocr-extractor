# %% [markdown]
# # O que faremos aqui

# %% [markdown]
# Neste notebook, iremos preparar as predições para serem submetidas ao site da competição. Lembrando que a estratégia que nós usamos foi escolher, para cada tarefa (campo a ser extraído) o modelo com melhor valor de word f1 nos dados de validação. Os melhores modelos escolhidos foram então treinados utilizando todos dados rotulados disponíveis (dados de treino e validação), com o número de epochs atingidos no checkpoint.
# Nos arquivos de submissão na competição, a resposta de cada campo será dada pelo modelo escolhido na fase anterior. Na tabela abaixo temos os modelos escolhidos para cada tarefa:

# %% [markdown]
# | Task                                    | Initial finetuning experiment id / name                                                   | Final finetuning experiment id / name|
# | :-:                                      | :-:                                                            | :-:      |
# | extract_company                   | [FIN-27 / t5-base_all_tasks_concat_newlines_as_spaces](https://ui.neptune.ai/marcospiau/final-project-ia376j-1/e/FIN-27/details) | [FIN-51 / FIN-27-t5-base_all_tasks_concat_newlines_as_spaces](https://ui.neptune.ai/marcospiau/final-project-ia376j-1/e/FIN-51/details)
# | extract_total                     | [FIN-38 / t5-base_extract_total_newlines_as_spaces](https://ui.neptune.ai/marcospiau/final-project-ia376j-1/e/FIN-38/details)  | [FIN-53 / all_labelled_data-FIN-38-t5-base_extract_total_newlines_as_spaces](https://ui.neptune.ai/marcospiau/final-project-ia376j-1/e/FIN-53/details)
# | extract_address                   | [FIN-41 / t5-base_extract_address_newlines_as_pipes](https://ui.neptune.ai/marcospiau/final-project-ia376j-1/e/FIN-41/details) | [FIN-50 / t5-all_labelled_data-FIN-41-t5-base_extract_address_newlines_as_pipes](https://ui.neptune.ai/marcospiau/final-project-ia376j-1/e/FIN-50/details)
# | extract_date                   | [FIN-28 / t5-base_all_tasks_concat_newlines_as_spaces](https://ui.neptune.ai/marcospiau/final-project-ia376j-1/e/FIN-28/details) | [FIN-52 / all_labelled_data-FIN-28-t5-base_all_tasks_concat_newlines_as_spaces](https://ui.neptune.ai/marcospiau/final-project-ia376j-1/e/FIN-52/details)

# %% [markdown]
# **extract_company**
#
# [FIN-27 / t5-base_all_tasks_concat_newlines_as_spaces](https://ui.neptune.ai/marcospiau/final-project-ia376j-1/e/FIN-27/details)
#
# [FIN-51 / FIN-27-t5-base_all_tasks_concat_newlines_as_spaces](https://ui.neptune.ai/marcospiau/final-project-ia376j-1/e/FIN-51/details)
#
# **extract_total**
#
# [FIN-38 / t5-base_extract_total_newlines_as_spaces](https://ui.neptune.ai/marcospiau/final-project-ia376j-1/e/FIN-38/details)
#
# [FIN-53 / all_labelled_data-FIN-38-t5-base_extract_total_newlines_as_spaces](https://ui.neptune.ai/marcospiau/final-project-ia376j-1/e/FIN-53/details)
#
# **extract_address**
#
# [FIN-41 / t5-base_extract_address_newlines_as_pipes](https://ui.neptune.ai/marcospiau/final-project-ia376j-1/e/FIN-41/details)
#
# [FIN-50 / t5-all_labelled_data-FIN-41-t5-base_extract_address_newlines_as_pipes](https://ui.neptune.ai/marcospiau/final-project-ia376j-1/e/FIN-50/details)
#
# **extract_date**
#
# [FIN-28 / t5-base_all_tasks_concat_newlines_as_spaces](https://ui.neptune.ai/marcospiau/final-project-ia376j-1/e/FIN-28/details)
#
# [FIN-52 / all_labelled_data-FIN-28-t5-base_all_tasks_concat_newlines_as_spaces](https://ui.neptune.ai/marcospiau/final-project-ia376j-1/e/FIN-52/details)

# %%
import os
from src.data.sroie import get_all_keynames_from_dir, load_labels
from src.evaluation.sroie_eval_utils import extract_base_keyname
from src.evaluation.sroie_eval_utils import save_predictions_in_dir

# %%
map_field_to_initial_exp = {
    'company': 'FIN-27',
    'total': 'FIN-38',
    'address': 'FIN-41',
    'date': 'FIN-28'
}

map_initial_exp_to_final_exp = {
    'FIN-27': 'FIN-51',
    'FIN-38': 'FIN-53',
    'FIN-41': 'FIN-50',
    'FIN-28': 'FIN-52'
}

map_field_to_final_exp = {
    k: map_initial_exp_to_final_exp[v]
    for k,v in map_field_to_initial_exp.items()
}
map_field_to_final_exp
# Out:
# {'company': 'FIN-51', 'total': 'FIN-53', 'address': 'FIN-50', 'date': 'FIN-52'}

# %%
predictions_basedir = "/home/marcospiau/final_project_ia376j/data/sroie_receipt_dataset/predictions"

def get_keynames_from_experiment(
    experiment_id,
    partition,
    predictions_basedir=predictions_basedir
):
    keynames_path = os.path.join(predictions_basedir, experiment_id, partition)
    return get_all_keynames_from_dir(keynames_path)

def get_labels_dict(keynames):
    """Loads labels (or predictions) for `keynames`.txt.
    """
    return {extract_base_keyname(x): load_labels(x) for x in keynames}

def get_predictions_for_experiment(exp_id, field):
    all_preds = get_labels_dict(get_keynames_from_experiment(exp_id, ''))
    filter_preds = {k: {field: v[field]} for k,v in all_preds.items()}
    return filter_preds

def merge_predictions_for_all_experiments(map_field_to_exp):
#     dict, where keys are the keynames, and the values are {field: prediction}
    broadcast_pred = [
        get_predictions_for_experiment(exp_id, field)
        for field, exp_id in map_field_to_exp.items()
    ]
#     keynames must be the same in all experiments
    keynames_set_list = [set(x.keys()) for x in broadcast_pred]
    keynames = keynames_set_list[0]
    assert all(keynames == x for x in keynames_set_list[1:])
    
    final_preds = {k: {} for k in keynames}
    for field_pred in broadcast_pred:
        for keyname_pred in keynames:
            final_preds[keyname_pred].update(field_pred[keyname_pred])
    return final_preds

# %%
final_test_predictions = merge_predictions_for_all_experiments(
    map_field_to_final_exp
)
final_test_predictions
# Out:
# {'X51005677336': {'company': 'SYARIKAT PERNIAGAAN GIN KEE',
#   'total': '22.26',
#   'address': 'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#   'date': '27/01/2018'},
#  'X51005745244': {'company': 'URBAN IDEA SDN BHD',
#   'total': 'RM11.23',
#   'address': 'A-6-06, DATARAN GLOMAC, JALAN SS6/5A, PUSAT BANDAR KELANA JAYA, 47301 PETALING JAYA, SELANGOR, MALAYSIA',
#   'date': '14/02/2018'},
#  'X51006349083': {'company': 'CHA FOR TEA',
#   'total': 'RM46.25',
#   'address': '1-1, CENTRAL PARK , JALAN PJU5/13, DATARAN SUNWAY, 47810 KOTA DAMANSARA, SELANGOR',
#   'date': '19/04/2018'},
#  'X51006619569': {'company': 'MR. D.I.Y. (KUCHAI) SDN BHD',
#   'total': '26.40',
#   'address': 'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#   'date': '01-02-16'},
#  'X51007846400': {'company': 'KOREAN BBQ KOREAN DINE SDN BHD',
#   'total': '152.90',
#   'address': 'NO 4, JALAN PERMAS 10/5, BANDAR BARU PERMAS JAYA, 81750 JOHOR BAHRU, JOHOR.',
#   'date': '19/06/2018'},
#  'X51005442375': {'company': 'UNIHAKKA INTERNATIONAL SDN BHD',
#   'total': '$8.50',
#   'address': '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#   'date': '25 MAR 2018'},
#  'X51008042779': {'company': 'RESTORAN WAN SHENG',
#   'total': '7.60',
#   'address': 'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#   'date': '05-05-2018'},
#  'X51005724623': {'company': 'KED 1PAN YEW CH. JAN',
#   'total': '312.70',
#   'address': 'LOT-76 JAIAN BANTING 200 DEN SELANGOR',
#   'date': '0803/2018'},
#  'X51005676534': {'company': 'SYARIKAT PERNIAGAAN GIN KEE',
#   'total': '72.08',
#   'address': 'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#   'date': '03/01/2018'},
#  'X51006414433': {'company': 'UNIHAKKA INTERNATIONAL SDN BHD',
#   'total': '$7.60',
#   'address': '12, JALAN TAMPOI 7/4KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#   'date': '06 APR 2018'},
#  'X51007846303': {'company': 'UNIHAKKA INTERNATIONAL SDN BHD',
#   'total': 'RM6.70',
#   'address': '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#   'date': '08 JUN 2018'},
#  'X51007846361': {'company': '1 18 MJ MOOKATA HOUSE',
#   'total': '102.40',
#   'address': 'NO.7G, JALAN PERMAS 11, BANDAR BARU PERMAS JAYA, 81750 MASAI, JOHOR.',
#   'date': '11-06-2018'},
#  'X51007339127': {'company': 'SANYU STATIONERY SHOP',
#   'total': '3.00',
#   'address': 'NO. 31G&33G, JALAN SETIA INDAH X ;U13/X 40170 SETIA ALAM',
#   'date': '24/10/2017'},
#  'X51006349081': {'company': 'C W KHOO HARDWARE SDN BHD',
#   'total': '84.80',
#   'address': 'NO.50, JALAN PBS 14/11, KAWASAN PERINDUSTRIAN BUKIT SERDANG,',
#   'date': '26/04/2018'},
#  'X51008030561': {'company': 'RESTORAN WAN SHENG',
#   'total': '17.60',
#   'address': 'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#   'date': '09-04-2018'},
#  'X51006556658': {'company': 'GARDENIA BAKERIES (KL) SDN BHD',
#   'total': '32.13',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#   'date': '15/08/2017'},
#  'X51007846397': {'company': 'UNIHAKKA INTERNATIONAL SDN BHD',
#   'total': 'RM7.70',
#   'address': '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#   'date': '21 JUN 2018'},
#  'X51006414512': {'company': 'BHPETROL PERMAS JAYA 2',
#   'total': '50.00',
#   'address': 'LOT PTD 101051 JALAN PERMAS 10/10 81750 MASAI, JOHOR',
#   'date': '03-04-2018'},
#  'X510056849111': {'company': 'WESTERN EASTERN ST TIONERY SDN. BHD',
#   'total': 'RM7.40',
#   'address': '42-46, JLN SULTAN AZLAN SHAH 51200 KUALA LUMPUR',
#   'date': '26-02-2018'},
#  'X51005230621': {'company': 'SIN LIANAP SDN BHD',
#   'total': '7.30',
#   'address': 'LOT 13, JALAN IPOH, KG BATU 30 ,ULU YAM LAMA 44.300 BTG KALI, SELANGOR',
#   'date': '05/02/2018'},
#  'X51009568881': {'company': 'HON HWA HARDWARE TRADING',
#   'total': '10.40',
#   'address': 'NO 37, JALAN MANIS 7, TAMAN SEGAR, 56100 CHERAS, KUALA LUMPUR.',
#   'date': '21/09/2017'},
#  'X51006556657': {'company': 'GARDENIA BAKERIES (KL) SDN BHD',
#   'total': '59.31',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#   'date': '16/08/2017'},
#  'X51005230605': {'company': 'PETRON BKT LANJAN SBALSERKAM ENTERPRISE',
#   'total': '4.90',
#   'address': 'KM 458,4 BKT LANJAN UTARA, L/RAYA UTARA SELATAN, SG BULOH 47000 SUNGAI BUL',
#   'date': '01/02/2018'},
#  'X51006619704': {'company': 'MR. D.I.Y. (M) SDN BHD',
#   'total': '32.80',
#   'address': 'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#   'date': '11-01-16'},
#  'X51006414728': {'company': 'KEPAN ORE E ALIMENT SDN. BHD.',
#   'total': '13.00',
#   'address': 'LOT LG10, AEON TAMMAN UNITI SHOPPING CITY, NO.4, JALAN PENDIDAK, TAMAN UNITI SHOPPING CITY, NO.4, JALAN PENDIDAK, TAMAN UNITI',
#   'date': '29-APR-2018'},
#  'X51007103597': {'company': '8 DON DUPLEJAD',
#   'total': '10.00',
#   'address': 'NO 5, JALAN KENARI 2, BANDAR PUCHONG JAYA, 47100 PUCHONG, SELANGOR',
#   'date': '11-APR-2018'},
#  'X51005361908': {'company': 'TEO HENG STATIONERY & RUOKS',
#   'total': '127.20',
#   'address': 'NO.53, JALAN BESAR, 45600 BATANG BERJUNTAI SELANGOR DARUL EHSAN',
#   'date': '15/03/2018'},
#  'X51006349085': {'company': 'PLATINUM RACKING SDN BHD',
#   'total': '23.00',
#   'address': '8B, JALAN LUMPUR, OFF JALAN PUTRA, OFF JALAN PUTRA, 05100 ALOR SETAR, KEDAH.',
#   'date': '22/04/2018'},
#  'X51006619790': {'company': 'YIN MA (M) SDN. BHD.',
#   'total': '14.50',
#   'address': 'NO.2, JALAN UDANO SIAR 2, TAMAN SRI SEGAMBUT, 52000 KUALA LUMPUR',
#   'date': '19 JUN 2016'},
#  'X51007339109': {'company': 'SANYU STATIONERY SHOP',
#   'total': '8.70',
#   'address': 'NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM',
#   'date': '27/03/2017'},
#  'X51005663274': {'company': 'LIM SENG THO HARDWARE TRADING',
#   'total': '10.50',
#   'address': 'NO 7, SIMPANG OFF BATU VILLAGE, JALAN IPOH BATU 5, 51200 KUALA LUMPUR MALAYSIA',
#   'date': '08/02/2018'},
#  'X51006828200': {'company': 'YIM MID VALLEY',
#   'total': '21.60',
#   'address': 'TOT T-015b, LEVEL 3, MID VALLEY CITY, LINGKARAN SYED PUTRA, LINGKARAN SYED PUTRA, 59201 KUALA LUMPUR MALAYSIA.',
#   'date': '15/12/2017'},
#  'X51006556826': {'company': 'GARDENIA BAKERIES (KL) SDN BHD',
#   'total': '28.98',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#   'date': '27/09/2017'},
#  'X51005568892': {'company': 'EVERGREEN LIGHT SDN BHD',
#   'total': '26.00',
#   'address': 'NO.7-1, JALAN PUTERI 7/11, BANDAR PUTERI, 47100 PUCHONG, SELANGOR',
#   'date': '18/09/2017'},
#  'X51008042787': {'company': 'FISH FARM THAI RESTAURANT Veg FISH FARM THAI RESTAURANTS S/B',
#   'total': '412.90',
#   'address': 'KM 4 JLN AMPANG HULU LANGAT, 68000 AMAPNG, SELANGOR.',
#   'date': '01/05/2018'},
#  'X51005447859': {'company': 'PASARAYA BORONG PINTAR SDN BHD',
#   'total': '1.45',
#   'address': 'NO 19-G8 19-1& 19-2 JALAN TASIK UTAMA 4, MEDAN NIAGA TASIK DAMAI',
#   'date': '14/02/2018'},
#  'X51005230616': {'company': 'GERBANG ALAF RESTAURANTS SDN BHD',
#   'total': '38.90',
#   'address': 'LEVEL 6, BANGUNAN TH, DAMANSARA UPTOWN3 NO.3, JALAN SS21/39,47400 PETALING JAYA SELANGOR',
#   'date': '18/01/2018'},
#  'X51005806696': {'company': 'IMAGE PRINTEC (M) SDN BHD',
#   'total': '2.35',
#   'address': "NO. 12A-G, JALAN WANGSA DELIMA 11, D'WANGSA WANGSA MAJU, 53300 KUALA LUMPUR.",
#   'date': '23/02/2018'},
#  'X51006557507': {'company': 'GARDENIA BAKERIES (KL) SDN BHD',
#   'total': '35.88',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#   'date': '27/10/2017'},
#  'X51006556734': {'company': 'GARDENIA BAKERIES (KL) SDN BHD',
#   'total': '32.46',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#   'date': '04/08/2017'},
#  'X51007231341': {'company': 'UNIHAKKA INTERNATIONAL SDN BHD',
#   'total': '$8.20',
#   'address': '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#   'date': '03 MAY 2018'},
#  'X51006556851': {'company': 'GARDENIA BAKERIES (KLS) SDN BHD',
#   'total': '84.78',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#   'date': '12/09/2017'},
#  'X51009447842': {'company': 'PASARAYA BORONG PINTAR SDN BHD',
#   'total': '0.90',
#   'address': 'NO 19-G& 19-1& 19-2 JALAN TASIK UTAMA 4, MEDAN NIAGA TASIK DAMAI',
#   'date': '14/03/2018'},
#  'X51005268408': {'company': '99 SPEED MART S/B',
#   'total': '169.20',
#   'address': 'LOT P.T. 2811, JALAN ANGSA, TAMAN BERKELEY 41150 KLANG, SELANGOR 1413-SETIA ALAM 2',
#   'date': '14-08-17'},
#  'X51006387737': {'company': 'BEMED (SP) SDN. BHD.',
#   'total': '165.00',
#   'address': 'NO.49, JALAN DINAR GU13/, SUBANG PERDANA, 40150 SHAH ALAM,SELANGOR D.E.',
#   'date': '01/APR/2017'},
#  'X51006555835': {'company': 'GARDENIA BAKERIES (KL) SDN BHD',
#   'total': '37.90',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#   'date': '29/08/2017'},
#  'X51006647984': {'company': 'KELANA VEGETarian RESTAURANTS S/B',
#   'total': '64.50',
#   'address': '63867-P1, BLOCK D, THE Suite, JAYA ONE, NO. 72A, JALAN UNITITI, 46200, PETALING JAYA, SELANGOR.',
#   'date': '15/05/18'},
#  'X51005433518': {'company': 'UNIHAKKA INTERNATIONAL SDN BHD',
#   'total': '$8.20',
#   'address': '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#   'date': '07 MAR 2018'},
#  'X51007339122': {'company': 'SANYU STATIONERY SHOP',
#   'total': '8.70',
#   'address': 'NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM',
#   'date': '14/10/2017'},
#  'X51005719888': {'company': 'POTTERS GARDENIA SDN BHD',
#   'total': '39.80',
#   'address': 'BATAU 11, SGS BULOH, 47000 SELANGOR.',
#   'date': '04/01/2018'},
#  'X51005677327': {'company': 'SYARIKAT PERNIAGAAN GIN KEE',
#   'total': '36.04',
#   'address': 'NO 290, JALAN AIR PANAS. SETAPAK, 53200, KUALA LUMPUR',
#   'date': '01/02/2018'},
#  'X51007339119': {'company': 'SANYU STATIONERY SHOP',
#   'total': '2.00',
#   'address': 'NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM',
#   'date': '17/11/2017'},
#  'X51006857540': {'company': 'BECON STATIONER BECON ENTERPRISE SDN BHD',
#   'total': '270.10',
#   'address': 'NO.41G, JLN SS21/60, DAMANSARA UTAMA, 47400 PJ, SELANGOR.',
#   'date': '13-11-2017'},
#  'X00016469670': {'company': '*** COPY *** OJC MARKETING SDN BHD',
#   'total': '193.00',
#   'address': 'NO 2 & 4, JALAN BAYU 4, BANDAR SERI ALAM, 81750 MASAI, JOHOR',
#   'date': '15/01/2019'},
#  'X51005568866': {'company': 'POPULAR BOOK CO. (M) SDN BHD',
#   'total': '5.05',
#   'address': 'NO 8, JALAN 7/118B, DESA TUN RAZAK 56000 KUALA LUMPUR, MALAYSIA',
#   'date': '20/08/17'},
#  'X51005677333': {'company': 'SYARIKAT PERNIAGAAN GIN KEE',
#   'total': '101.76',
#   'address': 'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR',
#   'date': '31/01/2018'},
#  'X51008099047': {'company': 'RESTORAN WAN SHENG',
#   'total': '4.60',
#   'address': 'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#   'date': '21-06-2018'},
#  'X51006857126': {'company': 'SKL DAMANSARA ENTERPRISE',
#   'total': '28.80',
#   'address': '69G, JALAN SS21/60, DAMANSARA UTAMA, 47400 PETALING JAYA, SELANGOR',
#   'date': '28/07/17'},
#  'X51005663309': {'company': 'KOH SENG HARDWARE',
#   'total': '7.00',
#   'address': 'NO. 939, BATU LIMA, JALAN IPOH, 51200 KUALA LUMPUR.',
#   'date': '01/02/2018'},
#  'X51008099088': {'company': 'RESTORAN WAN SHENG',
#   'total': '2.30',
#   'address': 'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#   'date': '27-06-2018'},
#  'X51007231275': {'company': 'UNIHAKKA INTERNATIONAL SDN BHD',
#   'total': '$6.60',
#   'address': '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#   'date': '12 MAY 2018'},
#  'X51005675103': {'company': 'SYARIKAT PERNIAGAAN GIN KEE',
#   'total': '100.17',
#   'address': 'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR',
#   'date': '04/01/2018'},
#  'X51008030563': {'company': 'RESTORAN WAN SHENG',
#   'total': '6.00',
#   'address': 'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#   'date': '02-04-2018'},
#  'X51005719857': {'company': 'ALI BABA INTERNATIONAL SDN BHD',
#   'total': '23.80',
#   'address': 'LOT 26-27, LEVEL G2, JLN DUTAS 1, SOLARIS DUTAS, 50480 KL.',
#   'date': '19-02-2018'},
#  'X51005705727': {'company': 'KEDAI BUKU NEW ACHEIVERS',
#   'total': '38.15',
#   'address': 'NO. 12 & 14, JALAN JINJANG 27154 TAMAN ALAM MEGAH, SEKSYEN 27 40400 SHAH ALAM, SELANGOR D.E.',
#   'date': '28/12/2017'},
#  'X51005746210': {'company': 'SEGI CASH & CARRY SDN.BHD.',
#   'total': '145.10',
#   'address': 'PT17920 SEK U9, SHAH ALAM',
#   'date': '12 MAR 2018'},
#  'X51006619503': {'company': 'KEDAI UEAT & RUNCIT HONG NING SDN. BHD.',
#   'total': '2.50',
#   'address': 'NO.8, JALAN LANG KUNING, KEPONG BARU, KEPONG GUO (B) 1.42 STO31 2 MUTART',
#   'date': '21/12/16'},
#  'X51006828199': {'company': 'PU TIE (M) SDN BHD',
#   'total': 'RM36.95',
#   'address': 'LOT 2-25, SUNWAY VELOCITY MALAYSIA LINGKARAN SV, SUNWAY VELOCITY 55100 KUALA LUMPUR',
#   'date': '12/10/2017'},
#  'X51005677337': {'company': 'SYARIKAT PERNIAGAAN GIN KEE',
#   'total': '94.13',
#   'address': 'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#   'date': '02/02/2018'},
#  'X51006311714': {'company': 'GUARDIAN HEALTH AND BEAUTY SDN BHD',
#   'total': '22.45',
#   'address': 'SOLARIS MOUNT KIARA N0.8 & 10, GF SCLARIS MOUNT KUARA JLN SOLARIS 5',
#   'date': '01/01/18'},
#  'X51006008083': {'company': 'PRINT EXPERT SDN BHD',
#   'total': '119.55',
#   'address': 'NO 18, 20, 22, JALAN BUNGA TANJONG 2/16, 40000 SHAH ALAM, SELANGOR',
#   'date': '25/03/2018'},
#  'X51007231372': {'company': 'GL HANDICRAFT SDN BHD',
#   'total': '38.35',
#   'address': 'NO. 27, JALAN ATLANTA HEAD 8/4, TAMAN MALL ATLANTA, TAMAN MALL ATLANTA, 81100 JOHOR BAHRU.',
#   'date': '2018-05-01'},
#  'X51007846355': {'company': 'AEON CO. (M) BHD',
#   'total': '8.95',
#   'address': '3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMAN MALURI CHERAS, 55100 KUALA LUMPUR',
#   'date': '17/06/2018'},
#  'X51006557187': {'company': 'GARDENIA BAKERIES (KL) SDN BHD',
#   'total': '42.25',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#   'date': '16/10/2017'},
#  'X51005710963': {'company': 'TS TOOLS HANINANE 1 TACHIWEIT SIAR',
#   'total': '7.00',
#   'address': '59, JALAN BANDAR SATU, PUSAT BANDAR PUCHONG 47160, PUCHONG, SELANGOR',
#   'date': '21/03/2018'},
#  'X51006912959': {'company': 'MASNO**ROYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTOYALTO',
#   'total': '10.90',
#   'address': 'NO. 23, JALAN SUTERA TANJUNG 8/3, TAMAN SUTERA UTAMA 81300 SKUDAI JOHOR, MALAYSIA.',
#   'date': '09/05/2018'},
#  'X51005675104': {'company': 'SYARIKAT PERNIAGAAN GIN KEE',
#   'total': '190.80',
#   'address': 'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#   'date': '25/01/2018'},
#  'X51005742110': {'company': 'YONG CEN ENTERPRISE',
#   'total': '65.70',
#   'address': '9, JALAN SUBANG JASA 3, 40150 SHAH ALAM, SELANGOR.',
#   'date': '06/01/2018'},
#  'X51006557194': {'company': 'GARDENIA BAKERIES (KL) SDN BHD',
#   'total': '39.77',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#   'date': '13/10/2017'},
#  'X51006619863': {'company': '99 SPEED MART S/B',
#   'total': '2.10',
#   'address': 'LOT P.T. 33198, BATU 4 JALAN KAPAR, MUKIM KAPAR 42100 KLANG, SELANGOR 1181-TMN SRI SINAR',
#   'date': '08-06-16'},
#  'X51005568887': {'company': 'HON HWA HARDWARE TRADING',
#   'total': '7.20',
#   'address': 'NO 37, JALAN MANIS 7, TAMAN SEGAR 56100 CHERAS, KUALA LUMPUR',
#   'date': '20/04/2017'},
#  'X51006414708': {'company': 'RESTORAN HWA MUI SUTERA SDN BHD',
#   'total': '91.50',
#   'address': '50, JALAN SUTERA TANJUNG 5/4 TAMAN SUTERA UTAMA, 81300 SKUDAI,JOHOR',
#   'date': '29/04/2018'},
#  'X51006912976': {'company': 'THE TOAST F&B SDN BHD',
#   'total': '71.10',
#   'address': 'LOT 2110&2111 JALAN PERMAS UTARA BANDAR BARU PERMAS 81750, JOHOR BAHRU JOHOR',
#   'date': '19/05/2018'},
#  'X51007103668': {'company': 'MR. D.I.Y. (M) SDN BHD',
#   'total': '27.20',
#   'address': 'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#   'date': '22-04-18'},
#  'X51007231346': {'company': 'DE JELITA STESEN MIYA',
#   'total': '60.00',
#   'address': 'JLN PERMAS 9/5, BAR PERMAS JAYA 81750, JOHOR BAHRU',
#   'date': '02/05/18'},
#  'X51005301666': {'company': 'LIGHTROOM GALLERY SDN BHD',
#   'total': '278.80',
#   'address': 'NO: 28, JALAN ASTANA 1C, BANDAR BUKIT RAJA, 41050 KLANG SELANGOR D.E, MALAYSIA',
#   'date': '20/11/2017'},
#  'X51005444046': {'company': 'STAR GROCER SDN BHD',
#   'total': '66.15',
#   'address': 'NO 4, DESA PAWAN, OFF KAMPONG PAWAN, 55100 KUALA LUMPUR',
#   'date': '25/03/18'},
#  'X51006557209': {'company': 'GARDENIA BAKERIES (KL) SDN BHD',
#   'total': '33.84',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#   'date': '06/10/2017'},
#  'X51005724624': {'company': 'KEDAI PAPAN YEW CHUAN',
#   'total': '135.68',
#   'address': 'LOT 276 JALAN BANTING 43800 DENGKIL, SELANGOR',
#   'date': '16/03/2018'},
#  'X51006327960': {'company': "KING'S CONFECTIONERY S/B",
#   'total': '7.50',
#   'address': 'LOT NO. G23, GIANT KELANA JAYA LOT PT244, JLN PERBANDARAN 556/4 PUSAT BANDAR KELANA JAYA, PETALING',
#   'date': '05/02/17'},
#  'X51005663307': {'company': 'LA STATIONERY SDN BHD',
#   'total': '56.80',
#   'address': 'NO.8, JALAN 46/26, TAMAN SRI RAMPAI, TAMAN SRI RAMPAI, 53300 KUALA LUMPUR.',
#   'date': '09/02/2018'},
#  'X51005719903': {'company': 'GERBANG ALAF RESTAURANTS SDN BHD',
#   'total': '8.50',
#   'address': 'LEVEL 6, BANGUNAN TH, DAMANSARA UPTOWN3 NO.3, JALAN SS21/39, 47400 PETALING JAYA SELANGOR',
#   'date': '11/03/2018'},
#  'X51005663310': {'company': 'LIM SENG THO HARDWARE TRADING',
#   'total': '8.40',
#   'address': 'NO 7, SIMPANG OFF BATU VILLAGE, JALAN IPOH BATU 5,51200 KUALA LUMPUR MALAYSIA',
#   'date': '09/02/2018'},
#  'X51007846403': {'company': 'GF-S03B',
#   'total': '13.10',
#   'address': 'NO.33, JALAN SELADANG TAMAN ABD, 80250 JOHOR BAHRU, JOHOR, MALAYSIA.',
#   'date': '02/06/2018'},
#  'X51006557208': {'company': 'GARDENIA BAKERIES (KL) SDN BHD',
#   'total': '32.12',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#   'date': '07/10/2017'},
#  'X51005582745': {'company': 'MODERN DEPOT SDN BHD',
#   'total': '141.50',
#   'address': 'NO.19, PT18685, JALAN JAMBU MELAKA 2 JINJANG SELATAN, KEPONG.',
#   'date': '04/12/2016'},
#  'X51006828201': {'company': 'THE COFFEE BEAN & TEA LEAF (M) SDN. BHD.',
#   'total': '39.70',
#   'address': 'UNIT G047, GROUND FLOOR MID VALLEY MEGAL MALL MID VALLEY CITY, LINGKARAN SYED PUTRA 59200 KUALA LUMPUR',
#   'date': '15/12/2017'},
#  'X51006401845': {'company': 'DuY SOIL TRADING SDN. BHD',
#   'total': '25.90',
#   'address': '2 2A, JALAN KASUARA 1/KS 7, BANDAR BOTANIC, 41200 KLANG, SELANGOR',
#   'date': '04/02/2017'},
#  'X51006556723': {'company': 'GARDENIA BAKERIES (KL) SDN BHD',
#   'total': '-5.09',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#   'date': '03/08/2017'},
#  'X51006008166': {'company': 'FLORISM DE ART',
#   'total': '750.00',
#   'address': 'LOT 2.70.00, LEVEL 2, PAVILION KUALA LUMPUR, 168, JALAN BUKIT BINTANG, 55100 KUALA LUMPUR, MALAYSIA.',
#   'date': '14/01/2018'},
#  'X51005433543': {'company': 'UNIHAKKA INTERNATIONAL SDN BHD',
#   'total': '$8.20',
#   'address': '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#   'date': '13 MAR 2018'},
#  'X51007846290': {'company': 'UNIHAKKA INTERNATIONAL SDN BHD',
#   'total': 'RM8.20',
#   'address': '12, JALAN TAMPOI 774,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#   'date': '07 JUN 2018'},
#  'X51005724611': {'company': 'KEDAI PAPAN YEW CHUAN',
#   'total': '144.16',
#   'address': 'LOT 276 JALAN BANTING 43800 DENGKIL, SELANGOR',
#   'date': '21/03/2018'},
#  'X51006557173': {'company': 'GARDENIA BAKERIES (KL) SDN BHD',
#   'total': '32.26',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#   'date': '28/10/2017'},
#  'X51007579719': {'company': 'SOUP & PORRIDGE',
#   'total': '20.70',
#   'address': 'LOT S10NB & S12NB, RESTORAN JEJANTAS SG. BULOH, ARAH UTARA, PLUS BERHAD.',
#   'date': '05-06-2018'},
#  'X51006556806': {'company': 'GARDENIA BAKERIES (KL) SDN BHD',
#   'total': '3.82',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM SELANGOR.',
#   'date': '23/09/2017'},
#  'X51006008082': {'company': 'PRINT EXPERT SDN BHD',
#   'total': '204.20',
#   'address': 'NO 18, 20, 22, JALAN BUNGA TANJONG 2/16, 40000 SHAH ALAM, SELANGOR',
#   'date': '25/03/2018'},
#  'X51005675099': {'company': 'SUPER TERRACE SDN BHD',
#   'total': '132.50',
#   'address': 'NO. 18 & 19, TAMAN CITY, JALAN KUCHING, 52100 KUALA LUMPUR',
#   'date': '20/01/2018'},
#  'X51008042781': {'company': 'RESTORAN WAN SHENG',
#   'total': '1.90',
#   'address': 'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#   'date': '11-05-2018'},
#  'X51007225406': {'company': 'UNIPHARM PHARMACY',
#   'total': '24.90',
#   'address': 'B12, JALAN SS 15/4D, 47500 SUBANG JAYA,',
#   'date': '05/APR/2018'},
#  'X51006414717': {'company': 'AEON CO. (M) BHD',
#   'total': '24.10',
#   'address': '3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMAN MALURI CHERAS, 55100 KUALA LUMPUR',
#   'date': '12/04/2018'},
#  'X51006619784': {'company': 'SECURITY & OA TRADING',
#   'total': '41.88',
#   'address': 'LOT TC007 & 008, 3RD FLOOR, SG. WANG PLAZA',
#   'date': '716/2016'},
#  'X51005433556': {'company': 'YHM AEON TEBRAU CITY',
#   'total': '49.70',
#   'address': 'S117, SECOND FLOOR, AEON TEBRAU CITY, 1, JALAN DESA TEBRAU, TAMAN DESA TEBRAU, TAMAN DESA TEBRAU, TAMAN DESA TEBRAU, TAMAN DESA TEBRAU, TAMAN DESA TEBRAU, TAMAN DESA TEBRAU, TAMAN DESA TEBRAU, TAMAN DESA TEBRAU, TA',
#   'date': '11/03/2018'},
#  'X51006502540': {'company': 'GERBANG ALAF RESTAURANTS SDN BHD',
#   'total': '109.05',
#   'address': 'LEVEL 6, BANGUNAN TH, DAMANSARA UPTOWN3 NO.3, JALAN SS21/39, 47400 PETALING JAYA SELANGOR',
#   'date': '27/04/2018'},
#  'X51005763958': {'company': 'SUPER SEVEN CASH & CARRY DN BHD',
#   'total': 'RM59.00',
#   'address': 'NO. 1 JALAN EURO 1 OFF JALAN BATU TIGA SUNGAI BULOH SEKSYEN U3 SHAH ALAM, 40150',
#   'date': '27-01-2018'},
#  'X51006414425': {'company': 'UNIHAKKA INTERNATIONAL SDN BHD',
#   'total': '$6.90',
#   'address': '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#   'date': '05 APR 2018'},
#  'X51005719863': {'company': 'SEN LEE HEONG RESTAURANT CO NO.',
#   'total': '77.40',
#   'address': 'G-0-1,M.AVENUE NO.1,JLN 1/38A, SEGAMBUT BAHAGIA, 51200, K.LUMPUL',
#   'date': '12-01-2018'},
#  'X51006619869': {'company': "HOME'S HARMONY @ 1 UTAMA SHOPPING CENTRE (M) SDN. BHD.",
#   'total': '23.20',
#   'address': 'LOT 5319A, 2ND FLOOR, 1 UTAMA SHOPPING CENTRE - PHASE 2 PERSIARAN BANDAR UTAMA, 47800 PETALING JAYA, MALAYSIA',
#   'date': '12/06/2016'},
#  'X51006620437': {'company': '99 SPEED MART S/B',
#   'total': '14.20',
#   'address': 'LOT P.T. 33198, BATU 4 JALAN KAPAR, MUKIM KAPAR 42100 KLANG, SELANGOR 1558-TMN PUSAT KEPONG',
#   'date': '20-09-16'},
#  'X51005568885': {'company': 'EVERGREENLIGHT SDN BHD',
#   'total': '56.00',
#   'address': 'NO.7-1, ALAN PUTERI 741, BANDAR PUTERI, 47100 PUCHONG, SELANGOR',
#   'date': '10/07/2017'},
#  'X51005230648': {'company': 'CROSS CHANNEL NETWORK SDN. BHD.',
#   'total': '6.35',
#   'address': '47, JALAN MERANTI 1, SEK. 3, BANDAR UTAMA BATANG KALI, 44300 BATANG KALI, SELANGOR.',
#   'date': '29/01/2018'},
#  'X51006556648': {'company': 'GARDENIA BAKERIES (KL) SDN BHD',
#   'total': '55.14',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#   'date': '20/08/2017'},
#  'X51005663323': {'company': 'KOH SENG HARDWARE',
#   'total': '48.00',
#   'address': 'NO. 939, BATU LIMA, JALAN IPOH, 51200 KUALA LUMPUR.',
#   'date': '04/12/2017'},
#  'X51005719898': {'company': 'MR. D.I.Y. (KUCHAI) SDN BHD',
#   'total': '11.90',
#   'address': 'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#   'date': '19-03-18'},
#  'X51006329388': {'company': 'BEMED (SP) SDN. BHD.',
#   'total': '165.00',
#   'address': 'NO.49, JALAN OLHAR G V3/G, SUBANG PERDANA, 40150 SHAH ALAM, SELANGOR D.E.',
#   'date': '02/JAN/2017'},
#  'X51006556812': {'company': 'GARDENIA BAKERIES (KL) SDN BHD',
#   'total': '25.84',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#   'date': '14/09/2017'},
#  'X51006555833': {'company': 'GARDENIA BAKERIES (KL) SDN BHD',
#   'total': '1.52',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#   'date': '31/08/2017'},
#  'X51006401853': {'company': '99 SPEED MART S/B',
#   'total': '37.45',
#   'address': 'LOT P.T. 2811, JALAN ANGSA, TAMAN BERKELEY 41150 KLANG, SELANGOR 1299-SUBANG PERMAI',
#   'date': '07-02-17'},
#  'X51007339125': {'company': 'SANYU STATIONERY SHOP',
#   'total': '8.70',
#   'address': 'NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM',
#   'date': '24/09/2017'},
#  'X51005715007': {'company': 'KAISON FURNISHING SDN BHD',
#   'total': '18.70',
#   'address': 'LOT NO. 13-122, LEVEL 3, MYTOWN SHOPPING CENTRE, NO.6, JALAN COCHRANE, SEKSYEN 90 55100 KUALA LUMPUR.',
#   'date': '25-03-18'},
#  'X51007231276': {'company': 'UNIHAKKA INTERNATIONAL SDN BHD',
#   'total': '$8.20',
#   'address': '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#   'date': '02 MAY 2018'},
#  'X51007846358': {'company': 'OLD TOWN WHITE COFFE EXQUISITE GARDENIA SDN BHD',
#   'total': '28.00',
#   'address': 'LOT NO R134,GIANT HYPERMARKET PlentONG NO3, JALAN MASAI LAMA 81750 MASAI, JOHOR BAHRU',
#   'date': '03 JUN 18'},
#  'X51006556821': {'company': 'GARDENIA BAKERIES (KL) SDN BHD',
#   'total': '48.57',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR',
#   'date': '02/09/2017'},
#  'X51005746203': {'company': 'SUPER SEVEN CASH & CARRY SDN BHD',
#   'total': 'RM408.45',
#   'address': 'NO. 1 JALAN EURO 1 OFF JALAN BATU TIGA SUNGAI BULOH SEKSYEN U3 SHAH ALAM, 40150',
#   'date': '01-03-2018'},
#  'X51005230659': {'company': 'SWC ENTERPRISE SDN BHD',
#   'total': '0.45',
#   'address': 'NO. 5-7, JALAN MAHAGONI 7/1, SEKSEN 4, BANDAR Utama, 44300 BATANG KALI, SELANGOR.',
#   'date': '08/01/2018'},
#  'X51005764031': {'company': 'SUPER SEVEN CASH & CARRY SDN BHD',
#   'total': 'RM42.10',
#   'address': 'NO. 1 JALAN EURO 1 OFF JALAN BATU TIGA SUNGAI BULOH SEKSYEN U3 SHAH ALAM, 40150',
#   'date': '01-02-2018'},
#  'X51006335818': {'company': 'SEGI CASH & CARRY SDN.BHD',
#   'total': '27.00',
#   'address': 'PT17920, SEKSYEN U9, 40150 SHAH ALAM, SELANGOR DARUL EHSAN.',
#   'date': '06 FEB 2017'},
#  'X51006556829': {'company': 'GARDENIA BAKERIES (KL) SDN BHD',
#   'total': '38.55',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#   'date': '24/09/2017'},
#  'X51007103687': {'company': 'MR. D.I.Y. (M) SDN BHD',
#   'total': 'RM 1.90',
#   'address': 'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#   'date': '27-04-18'},
#  'X51007846288': {'company': 'UNIHAKKA INTERNATIONAL SDN BHD',
#   'total': 'RM7.25',
#   'address': '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#   'date': '06 JUN 2018'},
#  'X51007339116': {'company': 'SANYU SUPPLY SDN BHD',
#   'total': '21.90',
#   'address': 'NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM',
#   'date': '28/10/2017'},
#  'X51006619506': {'company': 'KEDAI UBAT & RUNCIT HONG NING SDN BHD',
#   'total': 'SR.38',
#   'address': 'NOB,JALAN LANG KUNING, KEPOHGBARII 32100 RUJALA LUMPUR',
#   'date': '24/12/10'},
#  'X51006556610': {'company': 'PINGHWAI TRADING SDN BHD',
#   'total': '393.00',
#   'address': 'NO.2, JALAN METRO PERDANA TIMUR 11, KEPONG ENTERPRENUERS PARK, OFF JALAN KEPONG 52100 KUALA LUMPUR',
#   'date': '22/08/2017'},
#  'X51006387660': {'company': 'TANJONGKAS BOOKCENTRE (PT) SDN BHD',
#   'total': '2.50',
#   'address': 'LOT F15, GIANT BANDAR PUTERI JALAN PUTERI 1/1, BOR PUTERI 47166 PUCHONG, SELANGOR',
#   'date': '02/04/2017'},
#  'X51005442382': {'company': 'UNIHAKKA INTERNATIONAL SDN BHD',
#   'total': '$6.60',
#   'address': '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,KAWASAN PERINDUSTRIAN TAMPOI,KAWASAN PERINDUSTRIAN TAMPOI,KAWASAN PERINDUSTRIAN TAMPOI,KAWASAN PERINDUSTRIAN TAMPOI,KAWASAN PERINDUSTRIAN TAMPOI,KAWASAN PERINDUSTRIAN TAMPOI,KAWASAN',
#   'date': '20 MAR 2018'},
#  'X51005746204': {'company': 'BENED (SP) SDN. BHD.',
#   'total': '308.70',
#   'address': 'NO.19, JALAN DLIAR G V3.G, SIGIBUT PERDAIS, 40150 SISI ALAM, sigor D.E.',
#   'date': '27/01/2018'},
#  'X51005705784': {'company': 'KEDAI BUKU NEW ACHEIVERS',
#   'total': '48.00',
#   'address': 'NO. 12 & 14, JALAN JINJANG 27154 TAMAN ALAM MEGAH, SEKSYEN 27 40400 SHAH ALAM, SELANGOR D.E.',
#   'date': '15/09/2017'},
#  'X51006388081': {'company': "KING'S CONFECTIONERY S/B",
#   'total': '27.50',
#   'address': 'NO. 20-A1, JALAN SS6/3, KELANA JATH, 47302 PETALING JAYA SELANGOR D.E',
#   'date': '21/05/17'},
#  'X51005711402': {'company': 'RESTORAN WAN SHENG',
#   'total': '9.60',
#   'address': 'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#   'date': '17-03-2018'},
#  'X51005719823': {'company': 'IBUPROFEN FILM COATED TAB',
#   'total': '44.94',
#   'address': 'NO.47,JALAN 3/36, BUKIT SRI BINTANG KEPONG 52100, KUALA LUMPUR',
#   'date': '29/01/2018'},
#  'X51006556810': {'company': 'GARDENIA BAKERIES (KL) SDN BHD',
#   'total': '23.02',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#   'date': '20/09/2017'},
#  'X51009453729': {'company': 'LIAN HING STATIONERY SDN BHD',
#   'total': '79.50',
#   'address': 'NO.32 & 33, JALAN SR 1/9, SEKSYEN 9, TAMAN SERDANG RAYA, 43300 SERI KEMBANGAN SELANGOR DARUL EHSAN',
#   'date': '27/03/2018'},
#  'X51005676535': {'company': 'SYARIKAT PERNIAGAAN GIN KEE',
#   'total': '89.04',
#   'address': 'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR',
#   'date': '30/12/2017'},
#  'X51007103610': {'company': 'MR. D.I.Y. (M) SDN BHD',
#   'total': '5.00',
#   'address': '107 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#   'date': '14-04-18'},
#  'X51005719889': {'company': 'HENG KEE DELIGHTS BAK KUT TEH.',
#   'total': '42.00',
#   'address': 'NO31, JALAN 3/62A, BANDAR MENJALARA KEPONG, KEPONG, KELANG KUT TEH, SOUP, 2.00 X 1.50 WHITE RICE (B)',
#   'date': '04/01/2018'},
#  'X51008099100': {'company': 'PAPPARICH BMC',
#   'total': '46.89',
#   'address': 'NO.19 & 21 JALAN TEMENGGUNG 23/9 BANDAR MAHKOTA CHERAS 43200 SELANGOR DARUL EHSAN, MALAYSIA',
#   'date': '29 JUN 18'},
#  'X51005711444': {'company': 'RESTORAN WAN SHENG',
#   'total': '4.80',
#   'address': 'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#   'date': '21-03-2018'},
#  'X51009008095': {'company': 'BOON SENG PAPER SDN BHD',
#   'total': '31.80',
#   'address': '12, JALAN BUNGA TANJUNG, 2/16 SEKSYEN 2, 40000 SHAH ALAM, SELANGOR',
#   'date': '19/03/2018'},
#  'X51006389894': {'company': "KING'S CONFECTIONERY S/B",
#   'total': '30.00',
#   'address': '3425, GROUND FLOOR ILN THERAPY, JINJANG UTARA 52100 K.L.',
#   'date': '10/10/17'},
#  'X51005447851': {'company': 'PASARAYA BORONG PINTAR SDN BHD',
#   'total': '1.70',
#   'address': 'NO 19-G& 19-1& 19-2 JALAN TASIK UTAMA 4, MEDAN NIAGA TASIK DAMAI',
#   'date': '30/01/2018'},
#  'X51007846289': {'company': 'MOONLIGHT CAKE HOUSE SDN BHD',
#   'total': 'RM15.00',
#   'address': 'NO.1, JALAN PERMAS 10/5, BANDAR BARU PERMAS JAYA 81750 JOHOR BAHRU, JOHOR.',
#   'date': '07/06/2018'},
#  'X51005361912': {'company': 'TEO HENG STATIONERY & BOOKS',
#   'total': '1.05',
#   'address': 'NO.53, JALAN BESAR, 45600 BATANG BERJUNTAI SELANGOR DARUL EHSAN',
#   'date': '29/01/2018'},
#  'X51006619509': {'company': 'GUDANG HASIL RESTAURANT SDN BHD',
#   'total': 'RM15.80',
#   'address': 'NO.33, LRG HANG JEBAT, MELAKA',
#   'date': '02-12-2016'},
#  'X51005764161': {'company': '99 SPEED MART S/B',
#   'total': '98.90',
#   'address': 'LOT P, T, 2811, JALAN ANGSA, TARAN BERKELEY 41150 KLANG, SELANGOR 1313-SUBANG BESTARI',
#   'date': '28-01-18'},
#  'X51006619567': {'company': 'KEDAI UBAT & RUNCIT HONG NING SDN. BHD.',
#   'total': '637.73',
#   'address': 'NO.8,JALAN LANG KUNING, KEPONG BARU, KEPONG JARU, RUNCIT HONG NING SDN. BHD.',
#   'date': '02/02/16'},
#  'X51007846304': {'company': 'UNIHAKKA INTERNATIONAL SDN BHD',
#   'total': 'RM7.50',
#   'address': '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#   'date': '05 JUN 2018'},
#  'X51006502534': {'company': 'FAMILYMART',
#   'total': '5.6',
#   'address': 'NO 10A, JALAN ASTAKA U8/83, BUKIT JELUTONG 40150 SHAH ALAM, SELANGOR, D.E.',
#   'date': '10/04/2018'},
#  'X51005676537': {'company': 'SYARIKAT PERNIAGAAN GIN KEE',
#   'total': '94.34',
#   'address': 'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#   'date': '03/01/2018'},
#  'X51006557169': {'company': 'GARDENIA BAKERIES (KL) SDN BHD',
#   'total': '5.00',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#   'date': '01/09/2017'},
#  'X51005757292': {'company': 'MR. D.I.Y. (M) SDN BHD',
#   'total': '6.60',
#   'address': 'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#   'date': '18-03-18'},
#  'X51006388089': {'company': 'YONG CEN ENTERPRISE',
#   'total': '103.00',
#   'address': '9, JALAN SUBANG JASA 3, 40150 SHAH ALAM, SELANGOR.',
#   'date': '21/05/2017'},
#  'X51007846321': {'company': 'CHERF HENRY RIBS HOUSE',
#   'total': '103.85',
#   'address': '4, JALAN KEBUDAHANAAN 1 TAMAN UNITI 81300, SKUDAI',
#   'date': '05/06/2016'},
#  'X51005288570': {'company': 'SECURE PARKING CORPORATION S/B',
#   'total': '23.18',
#   'address': 'RIVERWALK VILLAGE BATUT 3, JALAN IPOH 51200 KL.',
#   'date': '23.03.18'},
#  'X51007846283': {'company': 'AEON CO. (M) BHD',
#   'total': '147.45',
#   'address': '3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMAN MALURI CHERAS, 55100 KUALA LUMPUR',
#   'date': '03/06/2018'},
#  'X51005757282': {'company': 'TSH POWER HARDWARE TRADING',
#   'total': '24.50',
#   'address': '13-1, JALAN PJU 5/10, DATARAN SUNWAY, KOTA DAMANSARA, 47810, PETALING JAYA, SELANGOR',
#   'date': '12/09/2017'},
#  'X51006620192': {'company': "HOME'S HARMONY @ 1 UTAMA SHOPPING CENTRE (M) SDN. BHD.",
#   'total': '0.50',
#   'address': 'LOT 319A, 2ND FLOOR, 1 UTAMA SHOPPING CENTRE - P.T. 28 PERSIAN BANDAR UTAMA, 47800 PETALING JAYA, MALAYSIA',
#   'date': '01/05/2016'},
#  'X51006912998': {'company': 'BHPETROL PERMAS JAYA 2',
#   'total': '50.00',
#   'address': 'LOT PTD 101051 JALAN PERMAS 10/10 81750 MASAI, JOHOR',
#   'date': '08-05-2018'},
#  'X51005675914': {'company': 'BEYOND BROTHERS HARDWARE',
#   'total': '67.85',
#   'address': 'LOT 1-0-2, JLN 1/50, DIAMOND SQUARE OFF JLN GOMBAK 53000 KUALA LUMPUR',
#   'date': '10/1/2017'},
#  'X51008042786': {'company': 'GERBANG ALAF RESTAURANTS SDN BHD',
#   'total': '19.00',
#   'address': 'LEVEL 6, BANGUNAN TH, DAMANSARA UPTOWN3 NO.3, JALAN SS21/39, 47400 PETALING JAYA SELANGOR',
#   'date': '30-05/2018'},
#  'X51007339105': {'company': 'SANYU STATIONERY SHOP',
#   'total': '3.30',
#   'address': 'NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM',
#   'date': '05/04/2017'},
#  'X51008099086': {'company': 'RESTORAN WAN SHENG',
#   'total': '7.20',
#   'address': 'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#   'date': '29-06-2018'},
#  'X51005663300': {'company': 'LIM SENG THO HARDWARE TRADING',
#   'total': '7.00',
#   'address': 'NO 7, SIMPANG OFF BATU VILLAGE, JALAN IPOH BATU 5, 51200 KUALA LUMPUR MALAYSIA',
#   'date': '02/02/2018'},
#  'X51007339134': {'company': 'SANYU STATIONERY SHOP',
#   'total': '8.70',
#   'address': 'NO. 31G&33G, JALAN SETIA INDAH X ,U3/X 40170 SETIA ALAM',
#   'date': '06/10/2017'},
#  'X51007231331': {'company': 'UNIHAKKA INTERNATIONAL SDN BHD',
#   'total': '$7.80',
#   'address': '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#   'date': '11 MAY 2018'},
#  'X51005268275': {'company': 'LIGHTROOM GALLERY SDN BHD',
#   'total': '278.80',
#   'address': 'NO: 28, JALAN ASTANA 1C, BANDAR BUKIT RAJA, 41050 KLANG SELANGOR D.E, MALAYSIA',
#   'date': '20/11/2017'},
#  'X51005763964': {'company': 'YONG CEN ENTERPRISE',
#   'total': '65.70',
#   'address': '9, JALAN SUBANG JASA 3, 40150 SHAH ALAM, SELANGOR',
#   'date': '06/01/2018'},
#  'X51005749904': {'company': 'SWC ENTERPRISE SDN BHD',
#   'total': '2.00',
#   'address': '28-G, GROUND FLOOR, JALAN DINAR A 13/A,TMN SUBANG PERDANA, 40150 SHAH ALAM,SELANGOR.',
#   'date': '06/03/2018'},
#  'X51005711449': {'company': 'RESTORAN WAN SHENG',
#   'total': '4.80',
#   'address': 'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#   'date': '07-03-2018'},
#  'X51006389898': {'company': 'RESTORAN WAN SHE',
#   'total': '164.40',
#   'address': 'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#   'date': '29-09-2017'},
#  'X51006388068': {'company': 'SEGI CASH & CARRY SDN. BHD.',
#   'total': 'RM 317.30',
#   'address': 'P217920 SEK U9, SHAH ALAM',
#   'date': '11/05/17'},
#  'X51006913060': {'company': 'UNIHAKKA INTERNATIONAL SDN BHD',
#   'total': '$8.20',
#   'address': '2, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#   'date': '21 MAY 2018'},
#  'X51007339121': {'company': 'SANYU STATIONERY SHOP',
#   'total': '8.70',
#   'address': 'NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM',
#   'date': '12/09/2017'},
#  'X51007846387': {'company': 'BOOK TALK (MUTIARA RINI) SDN BHD',
#   'total': '9.30',
#   'address': 'NO.53 & 55, JALAN UTAMA 34, MUTIARA RINI, SKUDAI, JOHOR.',
#   'date': '21/6/2018'},
#  'X51005444040': {'company': 'BENS INDEPENDENT GROCER SDN. BHD',
#   'total': '133.70',
#   'address': 'LOT 6, JALAN BATAI, PLAZA BATAI, PLAZA BATAI, DAMANSARA HEIGHTS 50490, KUALA LUMPUR',
#   'date': '09/03/18'},
#  'X51007846268': {'company': 'UNIHAKKA INTERNATIONAL SDN BHD',
#   'total': 'RM10.35',
#   'address': '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#   'date': '02 JUN 2018'},
#  'X51006856982': {'company': 'GUARDIAN HEALTH AND BEAUTY SDN BHD',
#   'total': '108.21',
#   'address': 'LOT B-005-006, BASEMENT LEVEL 1 THE STARLING MALL JALAN SS21/60: DAMANSARA UTAMA.',
#   'date': '16/08/17'},
#  'X51005757233': {'company': 'GUARDIAN HEALTH AND BEAUTY SDN BHD',
#   'total': '9.95',
#   'address': 'IOI MALL 631 & 632, GDR FLR, IOI MALL BANDAR PUCHONG JAYA',
#   'date': '09/03/18'},
#  'X51005676548': {'company': 'SYARIKAT PERNIAGAAN GIN KEE',
#   'total': '11.13',
#   'address': 'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#   'date': '15/01/2018'},
#  'X51006414532': {'company': 'THE geoVENUE (FreeDOM OptiMUM SDN BHD',
#   'total': '98.00',
#   'address': 'C1 SEA FRONT, BERJAYA WCALLFRONT COMPLEX, 88 JALAN IMMANUTOR, Stulang LUT 80300, JOHOR BAHRU, JOHOR.',
#   'date': '6/4/2018'},
#  'X51006857137': {'company': '99 SPEED MART S/B',
#   'total': '45.70',
#   'address': 'LOT F.T. 1111, JALAN ANGSA, TAMAN BERKELEY 41150 KLANG, SELANGOR',
#   'date': '10-05-17'},
#  'X51005444044': {'company': '99 SPEED MART S/B',
#   'total': '5.35',
#   'address': 'LOT P.J. 11, JALON ANGSA, TAMAN BERKELEY 41150 KLANG, SELANGOR',
#   'date': '10-03-18'},
#  'X51005745298': {'company': '99 SPEED MART S/B',
#   'total': '10.00',
#   'address': 'LOT P.T. 2811, JALAN ANGSA, TAMAN BERKELEY 41150 KLANG, SELANGOR 1317-TRILLIUM SG BESI',
#   'date': '31-03-18'},
#  'X51006619779': {'company': 'YAM FRESH',
#   'total': 'RM7.95',
#   'address': 'NO.145G, JALAN RIMBUNAN RAYA 1, LAMAN RIMBUNAN KEPONG, 52100 KUALA LUMPUR',
#   'date': '2016-07-31'},
#  'X51005711443': {'company': 'RESTORAN WAN SHENG',
#   'total': '6.70',
#   'address': 'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#   'date': '23-03-2018'},
#  'X51006248253': {'company': 'DREAMS',
#   'total': '15.00',
#   'address': 'L2-047, LEVEL 2, VIVACITY MEGAMALL, JALAN WAN ALWI, 93350 KUCHING',
#   'date': '29/03/2018'},
#  'X51005587261': {'company': 'CHOP YEW LIAN',
#   'total': '30.00',
#   'address': 'LOT PT 5121, PER. KLANG, SEK, 27 40000 SHAH ALAM, SELANGOR',
#   'date': '23/03/17'},
#  'X51006350737': {'company': 'C W KHOO HARDWARE SDN BHD',
#   'total': '14.65',
#   'address': 'NO.50, JALAN PBS 14/11, KAWASAN PERINDUSTRIAN BUKIT SERDANG,',
#   'date': '31/03/2018'},
#  'X51005605332': {'company': 'POPULAR BOOK CO. (M) SDN BHD',
#   'total': '7.95',
#   'address': 'NO 8, JALAN 7/118B, DESA TUN RAZAK 56000 KUALA LUMPUR, MALAYSIA',
#   'date': '14/03/18'},
#  'X51005757308': {'company': 'MR. D.I.Y. (M) SDN BHD',
#   'total': 'RM 21.50',
#   'address': 'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#   'date': '21-03-18'},
#  'X51005746207': {'company': 'SUPER SEVEN CASH & CARRY SDN BHD',
#   'total': 'RM18.30',
#   'address': 'NO. 1 JALAN EURO 1 OFF JALAN BATU TIGA SUNGAI BULOH SEKSYEN U3 SHAH ALAM, 40150',
#   'date': '21-03-2018'},
#  'X51005806718': {'company': 'HUGO TRADING SDN BHD',
#   'total': '40.80',
#   'address': 'LOT 889, KOMPLEKS PASAR BORONG SELANGOR 43300 SERI KEMBANGAN, SEL',
#   'date': '13/01/2018'},
#  'X51006387973': {'company': 'GERBANG ALAF RADOURANT SDN BHD',
#   'total': '47.15',
#   'address': 'LEVEL 6, BANGUNAN TH, DAMANSARA UPTOWN3 NO.3, JALAN SS21/39, 47400 PETALING JAYA SELANGOR',
#   'date': '#23 2017'},
#  'X51006554841': {'company': 'WISMA YAP TIEH (TAG)',
#   'total': 'RM9.00',
#   'address': 'LOT 4674 & 4675 SELAYANG BATU 8 JALAN IPOH 68100 BATU CAVES',
#   'date': '27-10-2017'},
#  'X51007391390': {'company': 'SUPER.9 SDN. BHD.',
#   'total': '3.00',
#   'address': 'NO.3343, GROUND FLOOR, JALAN 18/32, TAMAN SRI SEDRANG, 43300 SERI KEMBANG, 603-9545 1212',
#   'date': '31/05/2018'},
#  'X51006619766': {'company': 'MR. D.I.Y. (M) SDN BHD',
#   'total': 'RM 59.20',
#   'address': 'LOT 1951-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#   'date': '10-01-16'},
#  'X51006008092': {'company': 'POPULAR BOOK CO. (M) SDN BHD',
#   'total': '30.70',
#   'address': 'NO 8, JALAN 7/118B, DESA TUN RAZAK 56000 KUALA LUMPUR, MALAYSIA',
#   'date': '08/03/18'},
#  'X51005719855': {'company': 'CHERO ROCKU SDN. BHD.',
#   'total': '181.55',
#   'address': 'LOT F355/35/6/757, FIRST FLOOR, RAINFOREST, 1 UTAMA SHOPPING CENTRE, LEBUH BANDAR UTAMA, 47800 PETALING JAYA',
#   'date': '19/02/2018'},
#  'X51006334742': {'company': "THE CUT STEAKHOUSE & BURGER'S",
#   'total': '167.55',
#   'address': 'LOT L1-4 STAR AVENUE MALL JALAN SUHALF U5/179 SEKSYEN U5 PLASAT COMMERSIL Arena BINANG 40150 SHAH ALAM, SELANGOR',
#   'date': '01-01-2017'},
#  'X51006334139': {'company': 'FIVE STAR CASH & CARRY',
#   'total': '90.00',
#   'address': 'G.23 & G.22, PLAZA SERI SETIA, NO.1 JALAN SS 9/1, 47300 PJ, SELANGOR.',
#   'date': '05/01/17'},
#  'X51005568889': {'company': 'HON HWA HARDWARE TRADING',
#   'total': '19.60',
#   'address': 'NO 37, JALAN MANIS 7, TAMAN SEGAR, 56100 CHERAS, KUALA LUMPUR.',
#   'date': '11/02/2017'},
#  'X51006913018': {'company': 'AEON CO. (M) BHD',
#   'total': '458.55',
#   'address': '3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMAN MALURI CHERAS, 55100 KUALA LUMPUR',
#   'date': '11/05/2018'},
#  'X51006619564': {'company': '99 SPEED MART S/B',
#   'total': '85.45',
#   'address': 'LOT P.T. 2811, JALAN ANGSA TAMAN BERKELEY 41150 KLANG, SELANGOR 1605-TMN SRI BINTANG',
#   'date': '06-12-16'},
#  'X51005365187': {'company': 'F&P PHARMACY',
#   'total': '31.90',
#   'address': 'NO.20, GROUND FLOOR, JALAN BS 10/6 TAMAN BUKIT SERDANG, SEKSYEN 10, 43300 SERI KEMBANGAN. SELANGOR DARUL EHSAN',
#   'date': '02/03/2018'},
#  'X51007579714': {'company': 'NASI KANDAR PELITA PELITA PELITA PERTAMA (M) SDN BHD',
#   'total': '61.70',
#   'address': 'NO.2-1, JALAN KAMARUDDIN ISA 31400 IPOH, PERAK DARUL RIDZUAN',
#   'date': '03/06/2018'},
#  'X51005676542': {'company': 'SYARIKAT PERNIAGAAN GIN KEE',
#   'total': '10.60',
#   'address': 'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.',
#   'date': '29/12/2017'},
#  'X51006328967': {'company': 'TANJONGMAS BOOKCENTRE (PJ) SDN BHD',
#   'total': '62.00',
#   'address': 'LOT F15, GIANT BANDAR PUTERI JALAN PUTERI 1/1, BDR PUTERI 47100 PUCHONG, SELANGOR',
#   'date': '17/03/2017'},
#  'X51006332641': {'company': 'VONG CEN ENTERPRISE',
#   'total': '19.10',
#   'address': '9, JALAN SUBANG JASA 3, 40150 SHAH ALAM, SELANGOR.',
#   'date': '14022017'},
#  'X51006619757': {'company': '99 SPEED MART S/B',
#   'total': '71.60',
#   'address': 'LOT P.T. 33198, BATU 4 JALAN KAPAR, MUKIN KAPAR 42100 KLANG, SELANGOR 1605-TMN SRI BINTANG',
#   'date': '13-01-16'},
#  'X51006414702': {'company': 'TRIPLE SIX POINT ENTERPRISE 666',
#   'total': '7.20',
#   'address': 'NO 14& 16 JALAN PERMAS 4/3 BANDAR BARU PERMAS JAYA',
#   'date': '23-04-2018'},
#  'X51006556654': {'company': 'GARDENIA BAKERIES (KL) SDN BHD',
#   'total': '-6.42',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#   'date': '18/08/2017'},
#  'X51007339161': {'company': 'SANYU STATIONERY SHOP',
#   'total': '2.30',
#   'address': 'NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM',
#   'date': '29/11/2017'},
#  'X51006619346': {'company': 'MR. D.I.Y. (M) SDN BHD',
#   'total': '96.90',
#   'address': 'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#   'date': '18-14-16'},
#  'X51007846310': {'company': 'MOONLIGHT CAKE HOUSE SDN BHD',
#   'total': 'RM28.20',
#   'address': 'NO.1, JALAN PERMAS 10/5, BANDAR BARU PERMAS JAYA 81750 JOHOR BAHRU, JOHOR.',
#   'date': '11/06/2018'},
#  'X51006414593': {'company': 'UNIHAKKA INTERNATIONAL SDN BHD',
#   'total': '$8.90',
#   'address': '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#   'date': '14 APR 2018'},
#  'X51005763999': {'company': 'SEGI CASH & CARRY SDNBHD',
#   'total': 'RM XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX',
#   'address': 'PT17920 SEK U9, SHAH ALAM',
#   'date': '06 JAN 2018'},
#  'X51006334819': {'company': 'BEMED (SP) SDN. BHD.',
#   'total': '203.00',
#   'address': 'NO.49, JALAN OLNAR G U3/6, SUBANG PERDANA, 40150 SHAH ALAM,SELANGOR D.E.',
#   'date': '20/JAIV/2017'},
#  'X51005746206': {'company': 'PANA JAYA ENTERPA SE',
#   'total': '105.00',
#   'address': 'NO. 10-G. GROUND FLOOR. JALAN DINAR D. U3/D. TAMAN SUBANG PERDANA, SEK US. 40150 SHAH ALAM, SELANGOR.',
#   'date': '21-03-2018'},
#  'X51005361906': {'company': 'TEO HENG STATIONERY & BOOKS',
#   'total': '27.35',
#   'address': 'NO.53,JALAN BESAR, 45600 BATANG BERSUNTAI SELANGOR DARUL EHSAN',
#   'date': '27/01/2018'},
#  'X51006913061': {'company': 'UNIHAKKA INTERNATIONAL SDN BHD',
#   'total': '$9.20',
#   'address': '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#   'date': '23 MAY 2018'},
#  'X51007339638': {'company': 'SETIA',
#   'total': '26.40',
#   'address': 'NO. 17-G, JALAN SETIA INAAN (X) U13/X, SETIA ALAM, SEKSYEN U13, 40170 SHAH ALAK,',
#   'date': '29/09/2017'},
#  'X51006857132': {'company': 'AEON CO. (M) BHD',
#   'total': '23.80',
#   'address': '3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMAN MALURI CHERAS, 55100 KUALA LUMPUR',
#   'date': '09/07/2017'},
#  'X51005442334': {'company': 'UNIHAKKA INTERNATIONAL SDN BHD',
#   'total': '$8.20',
#   'address': '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#   'date': '26 MAR 2018'},
#  'X51007339159': {'company': 'SANYU STATIONERY SHOP',
#   'total': '8.70',
#   'address': 'NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM',
#   'date': '16/12/2017'},
#  'X51006556865': {'company': 'GARDENIA BAKERIES (KL) SDN BHD',
#   'total': '62.82',
#   'address': "LOT 3, JALAN EL'ELABURU 23/1, 40300 SHAH ALAM, SELANGOR,",
#   'date': '06/09/2017'},
#  'X51006619842': {'company': 'YIN MA (M) SDN. BHD.',
#   'total': '50.00',
#   'address': 'NO.2, JALAN UDANG SIAR 2, TAMAN SRI SEGAMBUT, 52000 KUALA LUMPUR',
#   'date': '03 JUN 2016'},
#  'X51005442388': {'company': 'CONTENTO',
#   'total': '21.60',
#   'address': '15, JALAN PERMAS 10/7, PERMAS 81750 MASAI JOHOR',
#   'date': '20/03/18'},
#  'X51006619703': {'company': 'MR, DIY (KUCHAI) SDN BHD',
#   'total': 'RM 10.00',
#   'address': 'LOT 1851, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#   'date': '11-01-16'},
#  'X51005741929': {'company': 'MYDIN SDN BHD',
#   'total': '5.50',
#   'address': 'NO 13, 15, 17 & 19 JALAN NOVA Q 05/0, SEKSYEN U5, SUBANG BESTARI 40150 SHAH ALA SELANGOR DARUL EHSAN',
#   'date': '15/01/2018'},
#  'X51005442366': {'company': 'TRIPLE SIX POINT ENTERPRISE 666',
#   'total': '22.60',
#   'address': 'NO 148 16 JALAN PERMAS 4/3 BANDAR BARU PERMAS JAYA',
#   'date': '22-03-2018'},
#  'X51005806720': {'company': 'SATU KAMPUNG ENTERPRISE SDN BHD',
# ...
#  'X51006619764': {'company': 'MR. D.I.Y. (KUCHAI) SDN BHD',
#   'total': 'RM 34.40',
#   'address': 'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#   'date': '05-01-16'},
#  'X51006556827': {'company': 'GARDENIA BAKERIES (KL) SDN BHD',
#   'total': '53.96',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#   'date': '26/09/2017'},
#  'X51006008081': {'company': 'PRINT EXPERT SDN BHD',
#   'total': '226.60',
#   'address': 'NO 18, 20, 22, JALAN BUNGA TANJONG 2/16, 40000 SHAH ALAM, SELANGOR',
#   'date': '19/03/2018'},
#  'X51006555819': {'company': 'GARDENIA BAKERIES (KL) SDN BHD',
#   'total': '26.58',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#   'date': '23/07/2017'},
#  'X51007846360': {'company': 'IKANO HANDEL SDN BHD',
#   'total': '46.20',
#   'address': 'NO.33, JALAN HANDEL TAMAMAN DESA TEBRAU 81100 JOHOR BAHRU',
#   'date': '09/06/18'},
#  'X51005724628': {'company': 'KEDAI PAPAN YEW CHUAN',
#   'total': '84.80',
#   'address': 'LOT 276 JALAN BANTING 43800 DENGKIL, SELANGOR',
#   'date': '10/03/2018'},
#  'X51007846396': {'company': 'GERBANG LAF RESTAURANTS SDN BHD',
#   'total': '7.35',
#   'address': 'LEVEL 6, BANGUNAN TH, DAMANSARA UPTOWN3 NO.3, JALAN SS21/39,47400 PETAIING JAYA SELANGOR',
#   'date': '24/06/2018'},
#  'X51006556740': {'company': 'GARDENIA BAKERIIAS (KL) SDN BHD',
#   'total': '23.35',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#   'date': '01/08/2017'},
#  'X51006334766': {'company': 'MEI LET RESTAURANT',
#   'total': '59.35',
#   'address': 'NO 2, JALAN BULAN BM U5/BM, SEKSYEN U5, SEKSYEN U5, 40150 SHAH ALAM, SELANGOR',
#   'date': '12/01/2017'},
#  'X51007433809': {'company': 'SYARIKAT KAM LAI SEONG SDN BHD',
#   'total': '190.00',
#   'address': 'NO. 1442, JALAN SK 11/5, SERI KEMBANGAN 43300 SELANGOR',
#   'date': '08-03-2018'},
#  'X51005447842': {'company': 'PASARAYA BORONG PINTAR SDN BHD',
#   'total': '0.90',
#   'address': 'NO 19-G& 19-1& 19-2 JALAN TASIK UTAMA 4, MEDAN NIAGA TASIK DAMAI',
#   'date': '14/03/2018'},
#  'X51008099090': {'company': 'RESTORAN WAN SHENG',
#   'total': '4.80',
#   'address': 'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#   'date': '01-06-2018'},
#  'X51006392167': {'company': 'ANEKA INTERTRADE NOineTING SDN BHD',
#   'total': '23.80',
#   'address': '150B, JALAN TUDM, KGB BARU SUBANG 40150 SHAH ALAM, SELANGO: DARUL EHSAN, MALAYSIA.',
#   'date': '19/06/17'},
#  'X51005230657': {'company': 'CROSS CHANNEL NETWORK SDN. BHD.',
#   'total': '7.95',
#   'address': '47, JALAN MERANTI 1, SEK. 3, BANDAR UTAMA BATANG KALI, 44300 BATANG KALI, SELANGOR.',
#   'date': '31/12/2017'},
#  'X51006387950': {'company': 'AMANO MALAYSIA SDN BHD',
#   'total': 'RM1.00',
#   'address': '12 JALAN PENGACARA U1/48 TEMASYA INDUSTRIAL PARK 40150 SHAH ALAM SELANGOR',
#   'date': '30/04/2017'},
#  'X51007579725': {'company': 'THONG RECIPE',
#   'total': '58.70',
#   'address': '16G BLOCK B ,ZENITH CORPORATE PARK JALAN SS7/26, 47301 PETALING JAYA SELANGOR',
#   'date': '27/06/18'},
#  'X51006619700': {'company': 'MR. D.I.Y. (KUCHAI) SDN BHD',
#   'total': 'RM 8.10',
#   'address': 'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#   'date': '10-01-16'},
#  'X51005447844': {'company': 'RESTAURANT JIAWEI JIAWEI HOUSE',
#   'total': '110.00',
#   'address': '13, JLN ASIK UTAMA 8 MEDAN NIAGA DAMAI SG BESI 57000 KL',
#   'date': '23/2/2018'},
#  'X51007846282': {'company': 'MOONLIGHT CAKE HOUSE SDN BHD',
#   'total': 'RM16.20',
#   'address': 'NO.1, JALAN PERMAS 10/5, BANDAR BARU PERMAS JAYA 81750 JOHOR BAHRU, JOHOR.',
#   'date': '02/06/2018'},
#  'X51006557196': {'company': 'GARDENIA BAKERIES (KL) SDN BHD',
#   'total': '27.97',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#   'date': '11/10/2017'},
#  'X51006556728': {'company': 'GARDENIA BAKERIESG (KL) SDN BHD',
#   'total': '60.26',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#   'date': '07/08/2017'},
#  'X51005433548': {'company': 'PASAR MINI JIN SENG',
#   'total': '33.80',
#   'address': '379, JALAN PERMAS SATU, BANDAR BARU PERMAS JAYA BANDAR BARU PERMAS JAYA BANDAR BARU PERMAS JAYA BANDAR BARU PERMAS JAYA BANDAR BARU PERMAS JAYA BANDAR BARU PERMAS JAYA BANDAR BARU PERMAS JAYA BANDAR BARU PERMAS JAYA BANDAR BARU PERMAS JAYA BAND',
#   'date': '03/03/18'},
#  'X51005806692': {'company': 'GRAND ZONE HOUSEHOLD CENTRE SDN BHD',
#   'total': '367.30',
#   'address': '60 & 62. JALAN CITTU, 86000, KLUANG',
#   'date': '18/02/2018'},
#  'X51006008206': {'company': 'BERKA TOWER LOT SATMZ 23, MEzzaNINE LEVEL SANELITE BLOCK KUALASA LUMPUR International Airport DEWINA HOST SDN BHD',
#   'total': 'RM63.90',
#   'address': 'LOT SATMZ 23, MEzzaNINE LEVEL SATELITE BATTERY KUALALA LUMPUR International Airport DEWINA HOST SDN BAHDR (434286-P)',
#   'date': '2018/03/27'},
#  'X51006466070': {'company': 'WESTERN EASTERN ST TIONERY SDN. BHD',
#   'total': 'RM42.88',
#   'address': '42-46, JLN SULTAN AZLAN SHAH 51200 KUALA LUMPUR',
#   'date': '26-04-2018'},
#  'X51005447841': {'company': 'PASARAYA BORONG PINTAR SDN BHD',
#   'total': '10.40',
#   'address': 'NO 19-G& 19-1& 19-2 JALAN TASIK UTAMA 4, MEDAN NIAGA TASIK DAMAI',
#   'date': '09/03/2018'},
#  'X51006008090': {'company': 'POPULAR BOOK CO. (M) SDN BHD',
#   'total': '30.50',
#   'address': 'NO 8, JALAN 7/118B, DESA TUN RAZAK 56000 KUALA LUMPUR, MALAYSIA',
#   'date': '05/03/18'},
#  'X51007846379': {'company': 'AEON CO. (M) BHD',
#   'total': '79.45',
#   'address': '3RD FLR, AEON TAMAN MALURI SC JIN JEJAKA, TAMAN MALURI CHERAS, 55100 KUALA LUMPUR',
#   'date': '03/06/2018'},
#  'X51005745213': {'company': 'MUN HENG ELECTRICAL & HARDWARE SUPPLY',
#   'total': 'Amount.40',
#   'address': 'NO.52, JALAN BULAN US/BT, BANDAR PINGIRAN SUBANG, SUNGAI BULOH, 40150 SHALALI ALAN, SEI.',
#   'date': '01/02/2018'},
#  'X51006414600': {'company': 'AEON CO. (M) BHD',
#   'total': '50.90',
#   'address': '3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMAN MALURI CHERAS, 55100 KUALA LUMPUR',
#   'date': '14/04/2018'},
#  'X51005806719': {'company': 'SATU KAMPUNG ENTERPRISE SDN BHD',
#   'total': '63.00',
#   'address': 'NO.42, PASAR BORONG SELANGOR JALAN PUTRA PERMAI, 43300 SERI KEMBANGAN, SELANGOR',
#   'date': '13/01/201'},
#  'X51007846372': {'company': 'UNIHAKKA INTERNATIONAL SDN BHD',
#   'total': 'RM10.15',
#   'address': '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#   'date': '14 JUN 2018'},
#  'X51005605287': {'company': 'AEON CO. (M) BHD',
#   'total': '12.25',
#   'address': '3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMAN MALURI CHERAS, 55100 KUALA LUMPUR',
#   'date': '14/03/2018'},
#  'X51006414427': {'company': 'UNIHAKKA INTERNATIONAL SDN BHD',
#   'total': '$7.60',
#   'address': '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#   'date': '04 APR 2018'},
#  'X51005684949': {'company': 'WESTERN EASTERN ST TIONERY SDN. BHD',
#   'total': 'RM7.40',
#   'address': '42-46, JLN SULTAN AZLAN SHAH 51200 KUALA LUMPUR',
#   'date': '26-02-2018'},
#  'X51006414715': {'company': 'SECRET RECIPE RESTAURANT',
#   'total': 'RM41.81',
#   'address': 'LOT G16, PERMAS JAYA JUSCO',
#   'date': '4/22/2018'},
#  'X51007846371': {'company': 'UNIHAKKA INTERNATIONAL SDN BHD',
#   'total': 'RM8.85',
#   'address': '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#   'date': '13 JUN 2018'},
#  'X51007231343': {'company': 'UNIHAKKA INTERNATIONAL SDN BHD',
#   'total': '$5.60',
#   'address': '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#   'date': '04 MAY 2018'},
#  'X51006008093': {'company': 'POPULAR BOOK CO. (M) SDN BHD',
#   'total': '12.15',
#   'address': 'NO 8, JALAN 7/118B, DESA TUN RAZAK 56000 KUALA LUMPUR, MALAYSIA',
#   'date': '06/03/18'},
#  'X51006619507': {'company': 'GOLDEN ARCHES RESTAURANTS SDN BHD',
#   'total': '14.70',
#   'address': 'LEVEL 6, BANGUNAN TH, DAMANSARA UPTOWN3 NO.3, JALAN SS21/39, 47400 PETALING JAYA SELANGOR',
#   'date': '03/12/2016'},
#  'X51006401977': {'company': 'B & BEST RESTAURANT',
#   'total': '1485.15',
#   'address': '10.2, JA AN SS4C/5,PETALING JAYA SE ANGOR DARUL EHSAN',
#   'date': '19/04/2017'},
#  'X51006556808': {'company': 'GARDENIA BAKERIES (KL) SDN BHD',
#   'total': '79.26',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#   'date': '22/09/2017'},
#  'X51006438346': {'company': 'HIGH FIVE ENTERPRISE',
#   'total': '95.48',
#   'address': 'JALAN BIDARRA, TAMAN BIDARRA, SELANGOR 68100, BATU CAVES, SELANGOR',
#   'date': '05/04/18'},
#  'X51005361923': {'company': 'SWC ENTERPRISE SDN BHD',
#   'total': '50.20',
#   'address': '8 % 10, JALAN IJOK PERMA 1 PUSAT NIGA IJOK PERMA, 48000 IJOK, SELANGOR.',
#   'date': '02/01/2018'},
#  'X51007846266': {'company': 'UNIHAKKA INTERNATIONAL SDN BHD',
#   'total': 'RM8.75',
#   'address': '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#   'date': '01 JUN 2018'},
#  'X51005200931': {'company': 'PERNIAGAAN ZHENG HUY',
#   'total': '436.20',
#   'address': 'NO.59 JALAN PERMAS 9/5 BANDAR BARU PERMAS JAYA 81750 JOHOR BAHRU',
#   'date': '09/02/2018'},
#  'X51008042780': {'company': 'RESTORAN WAN SHENG',
#   'total': '7.20',
#   'address': 'NO.2, JALAN TEMENGGUNG 19/9, SEKSYEN 9, BANDAR MAHKOTA CHERAS, 43200 CHERAS, SELANGOR',
#   'date': '10-05-2018'},
#  'X51006329183': {'company': 'SEMBOYAN TEGAS SDN BHD',
#   'total': '27.00',
#   'address': 'NO.5 & 7JALAN TSJ 2. TAMAN SUBANG JASA KGM, BARU SUBANG, 40150 SHAH ALAM SELANGOR DARUL EHSAN',
#   'date': '06-03-2018'},
#  'X51007231364': {'company': 'GERBANG ALAF RESTAURANTS SDN BHD',
#   'total': '32.25',
#   'address': 'LEVEL 6, BANGUNAN TH, DAMANSARA UPTOWN3 NO.3, JALAN SS21/39,47400 PETALING JAYA SELANGOR',
#   'date': '26/05/2018'},
#  'X51007103649': {'company': 'MR. D.I.Y(M)SDN BHD',
#   'total': '48.90',
#   'address': 'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#   'date': '21-04-18'},
#  'X51007339163': {'company': 'SANYU STATIONERY SHOP',
#   'total': '10.90',
#   'address': 'NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM',
#   'date': '23/11/2017'},
#  'X51006619570': {'company': 'MR. D.I.Y. (M) SDN BHD',
#   'total': '30.90',
#   'address': 'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#   'date': '21-02-16'},
#  'X51006008105': {'company': 'AEON CO. (M) BHD',
#   'total': '65.10',
#   'address': '3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMAN MALURI CHERAS, 55100 KUALA LUMPUR',
#   'date': '21/03/2018'},
#  'X51006328937': {'company': 'OLIVE9 PHARMACY SDN BHD',
#   'total': '12.15',
#   'address': '69 JALAN NOVA U5/N, RESTEN U5 SUBANG KE',
#   'date': '31/03/2017'},
#  'X51005337877': {'company': 'UROKO JAPANESE CUISINE SDN BHD',
#   'total': '53.00',
#   'address': '22A-1, JALAN 17/54, SECTION 17, 46400 PETALING JAYA, SELANGOR',
#   'date': '20/03/2018'},
#  'X51006733495': {'company': '99 SPEED MART S/B',
#   'total': '14.20',
#   'address': 'LOT P.T. 33198, BATU 4 JALAN KAPAR, MUKIM KAPAR 42100 KLANG, SELANGOR 1558-TMN PUSAT KEPONG',
#   'date': '19-10-16'},
#  'X51006913032': {'company': 'UNIHAKKA INTERNATIONAL SDN BHD',
#   'total': '$12.20',
#   'address': '12, JALAN TAMPOI 7/4,KAWASAN PERINDUSTRIAN TAMPOI,81200 JOHOR BAHRU,JOHOR',
#   'date': '10 MAY 2018'},
#  'X51005724552': {'company': 'KEDAI PAPAN YEW CHUAN',
#   'total': '68.90',
#   'address': 'LOT 276 JALAN BANTING 43800 DENGKIL, SELANGOR',
#   'date': '21/03/2018'},
#  'X51006557115': {'company': 'GARDENIA BAKERIES (KL) SDN BHD',
#   'total': '35.58',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#   'date': '02/10/2017'},
#  'X51005764154': {'company': 'PANA JAYA ENTERPRISE',
#   'total': '205.50',
#   'address': 'NO. 10-G. GAOUND FLOOR, JALAN DINAR D. UB/D TAMAN SUBANG PERDANA. SEK UB. 40150 SHAH ALAM, SELANGOR',
#   'date': '25-01-2018'},
#  'X51005605295': {'company': 'ECONSAVE CASH & CARRY (FC) SDN BHD',
#   'total': '5.15',
#   'address': 'LOT G01, KL FESTIVATE CITY, NO.67 JLN IBU KOTA TAN DANAU KOTA, KL',
#   'date': '22/03/18'},
#  'X51005577191': {'company': 'FY EAGLE ENTERPRISE',
#   'total': '8.00',
#   'address': 'TAMAN PERINDUSTRIAN BUKIT SERDANG, 43300 SERI KEMBANGAN, GST NO: 001663156274',
#   'date': '07/12/2017'},
#  'X51006387931': {'company': 'AMANO MALAYSIA SDN BHD',
#   'total': 'RM3.00',
#   'address': '12 JALAN PENGACARA U1/48 TEMASYA INDUSTRIAL PARK 40150 SHAH ALAM SELANGOR',
#   'date': '30/04/2017'},
#  'X51005444041': {'company': 'BENS INDEPENDENT GROCER SDN. BHD',
#   'total': '81.00',
#   'address': 'LOT 6, JALAN BATAI, PLAZA BATAI, PLAZA BATAI, DAMANSARA HEIGHTS 50490, KUALA LUMPUR',
#   'date': '08/03/18'},
#  'X51005568895': {'company': 'VIVOPAC MARKETING SDN BHD',
#   'total': '52.45',
#   'address': '14 JALAN MANIS 4 TAMAN SEGAR 56100 KL',
#   'date': '13/09/2017'},
#  'X51006619338': {'company': '99 SPEED MART S/B',
#   'total': '262.20',
#   'address': 'LOT P.T. 33198, BATU 4 JALAN KAPAR, MUKIK KAPAR 42100 KLANG, SELANGOR 1320-TMN BATU',
#   'date': '31-01-16'},
#  'X51006556809': {'company': 'GARDENIA BAKERIES (KL) SDN BHD',
#   'total': '43.36',
#   'address': 'LOT 3, JALAN PELABUR 23/1, 40300 SHAH ALAM, SELANGOR.',
#   'date': '21/09/2017'},
#  'X51007339160': {'company': 'SANYU STATIONERY SHOP',
#   'total': '3.90',
#   'address': 'NO. 31G&33G, JALAN SETIA INDAH X ,U13/X 40170 SETIA ALAM',
#   'date': '21/12/2017'},
#  'X51005621482': {'company': 'PREMIO STATIONERY SDN BHD',
#   'total': '13.40',
#   'address': 'NO 57, JALAN SS 3/29, 47300 PETALING JAYA, SELANGOR.',
#   'date': '20/03/2018'},
#  'X51006620175': {'company': 'MR. D.I.Y. (M) SDN BHD',
#   'total': '26.70',
#   'address': 'LOT 1851 -A & 1831-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#   'date': '06-05-16'},
#  'X51005719905': {'company': 'SAINT HEART PASTRY',
#   'total': '8.20',
#   'address': '29, JLN SJ 17TMN SELAYANG JAYA, 68100 BATU CAVES, SELANGOR',
#   'date': '25/03/2018'},
#  'X51006328345': {'company': "KING'S CONFECTIONERY S/B",
#   'total': '7.20',
#   'address': 'NO. 20-A1, JALAN SS5/3, KELANA JAYA, 473 PETALING JAYA SELANGOR D.E.',
#   'date': '23/02/17'},
#  'X51005724626': {'company': 'KEDAI PAPAN YEW CHUAN',
#   'total': '270.30',
#   'address': 'LOT 276 JALAN BANTING 43800 DENGKIL, SELANGOR',
#   'date': '02/04/2018'},
#  'X51005442322': {'company': "TONY ROMA'S AEON TEBRAU CITY GRAND COMPANIONS SDN BHD",
#   'total': '269.40',
#   'address': 'LOT G112, AEON MALL TEBRAU CITY NO 1 JALAN DESA TEBRAU 81100 JOHOR BAHRU',
#   'date': '03 MAR 19'},
#  'X51006334927': {'company': 'KELANA JAYA, 47301 PETALING SELANGOR DARUL EHSAN.',
#   'total': '6.40',
#   'address': 'NO:001684044-P KELANA JAYA, 47301 PETALING SELANGOR DARUL EHSAN.',
#   'date': '1/11/16'},
#  'X00016469671': {'company': 'OJC MARKETING SDN BHD',
#   'total': '170.00',
#   'address': 'NO 2 & 4, JALAN BAYU 4, BANDAR SERI ALAM, 81750 MASAI, JOHOR',
#   'date': '02/01/2019'},
#  'X51005568894': {'company': 'VIVOPAC MARKETING SDN BHD',
#   'total': '46.65',
#   'address': '14 JALAN MANIS 4 TAMAN SEGAR 56100 KL',
#   'date': '17/01/2017'},
#  'X51005442343': {'company': 'YONG TAT HARDWARE TRADING',
#   'total': '72.00',
#   'address': 'NO 4,JALAN PERJIRANAN 10, TAMAN AIR BIRU, 81700 PASIR GUDANG, JOHOR',
#   'date': '13/03/2018'},
#  'X51005724622': {'company': 'KEDAI PAPAN YEW CHUAN',
#   'total': '91.16',
#   'address': 'LOT 276 JALAN BANTING 43800 DENGKIL, SELANGOR',
#   'date': '07/03/2018'},
#  'X51005705729': {'company': 'ASO ELECTRICAL TRADING SDN BHD',
#   'total': '94.60',
#   'address': 'NO 31G, JALAN SEPADU C 25/C. SECTION 26, TAMAN INDUSTRIES, AXIS 40400 SHAH ALAM, SELANGOR.',
#   'date': '13/10/2017'},
#  'X51006334770': {'company': 'S&Y STATIONERY',
#   'total': '1.40',
#   'address': 'NO. 36G JALAN BULAN BM U5/BM, BANDAR PINGGIRAN SUBANG, SEKSYEN U5, 40150 SHAH ALAM, SELANGOR.',
#   'date': '09-JAN-2017'},
#  'X51006619760': {'company': 'KEDAI UBAT & RUNCIT HONG NING SDN. BHD.',
#   'total': '29.10',
#   'address': 'NO.3,JALAN LANG KUNING, KEPONGBARIJ, KEPONGBARIJ, 32100 KUALA LUMPUR',
#   'date': '0201/16'},
#  'X51006647933': {'company': 'RESTORAN HOETIM',
#   'total': 'RM83.00',
#   'address': '1-G, JALAN OS 1/3,ONE SELAYANG OFF JALAN RAWANG 68100 B.CAVES',
#   'date': '28/05/2018'}}

# %%
submissions_path = "/home/marcospiau/final_project_ia376j/data/sroie_receipt_dataset/submissions/v1_checkpoint_selection_by_task"

# %%
save_predictions_in_dir(final_test_predictions, submissions_path)
# Out:
# Saving predictions in /home/marcospiau/final_project_ia376j/data/sroie_receipt_dataset/submissions/v1_checkpoint_selection_by_task: 100%|██████████| 347/347 [00:00<00:00, 16216.78it/s]

# %% [markdown]
# Não está registrado aqui, mas, a critério de teste, também vou tentar uma submissão utilizando o melhor modelo único ([FIN-28 / t5-base_all_tasks_concat_newlines_as_spaces](https://ui.neptune.ai/marcospiau/final-project-ia376j-1/e/FIN-28/details) | [FIN-52 / all_labelled_data-FIN-28-t5-base_all_tasks_concat_newlines_as_spaces](https://ui.neptune.ai/marcospiau/final-project-ia376j-1/e/FIN-52/details)), que por acaso também é o mesmo modelo que foi o melhor para o campo `date`.

# %%
os.listdir(f'{submissions_path}/..')
# Out:
# ['v1_checkpoint_selection_by_task.zip',
#  'v2_single_model_initial=FIN-28_final=FIN-52',
#  'v1_checkpoint_selection_by_task',
#  'v2_single_model_initial=FIN-28_final=FIN-52.zip']
